# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/deepconvolution-gan/gan_data_epoch_150
# /kaggle/input/deepconvolution-gan/gan_data_epoch_30
# /kaggle/input/deepconvolution-gan/gan_data_epoch_1
# /kaggle/input/deepconvolution-gan/gan_data_epoch_200
# /kaggle/input/deepconvolution-gan/__results__.html
# /kaggle/input/deepconvolution-gan/gan_data_epoch_100
# /kaggle/input/deepconvolution-gan/gan_data_epoch_10
# /kaggle/input/deepconvolution-gan/gan_data_epoch_40
# /kaggle/input/deepconvolution-gan/gan_data_epoch_20
# /kaggle/input/deepconvolution-gan/__notebook__.ipynb
# /kaggle/input/deepconvolution-gan/gan_data_epoch_50
# /kaggle/input/deepconvolution-gan/__output__.json
# /kaggle/input/deepconvolution-gan/custom.css
# /kaggle/input/mnist-splitter-newtensor/__results__.html
# /kaggle/input/mnist-splitter-newtensor/MNIST.tar.gz
# /kaggle/input/mnist-splitter-newtensor/svload
# /kaggle/input/mnist-splitter-newtensor/stload
# /kaggle/input/mnist-splitter-newtensor/__notebook__.ipynb
# /kaggle/input/mnist-splitter-newtensor/__output__.json
# /kaggle/input/mnist-splitter-newtensor/custom.css
# /kaggle/input/mnist-splitter-newtensor/MNIST/processed/training.pt
# /kaggle/input/mnist-splitter-newtensor/MNIST/processed/test.pt
# /kaggle/input/mnist-splitter-newtensor/MNIST/raw/t10k-labels-idx1-ubyte
# /kaggle/input/mnist-splitter-newtensor/MNIST/raw/t10k-images-idx3-ubyte.gz
# /kaggle/input/mnist-splitter-newtensor/MNIST/raw/t10k-labels-idx1-ubyte.gz
# /kaggle/input/mnist-splitter-newtensor/MNIST/raw/train-labels-idx1-ubyte.gz
# /kaggle/input/mnist-splitter-newtensor/MNIST/raw/t10k-images-idx3-ubyte
# /kaggle/input/mnist-splitter-newtensor/MNIST/raw/train-labels-idx1-ubyte
# /kaggle/input/mnist-splitter-newtensor/MNIST/raw/train-images-idx3-ubyte
# /kaggle/input/mnist-splitter-newtensor/MNIST/raw/train-images-idx3-ubyte.gz
# /kaggle/input/mnist-splitter/stdash_dataloader
# /kaggle/input/mnist-splitter/svdash_dataloader
# /kaggle/input/aae-gan/80800.png
# /kaggle/input/aae-gan/170400.png
# /kaggle/input/aae-gan/28800.png
# /kaggle/input/aae-gan/148400.png
# /kaggle/input/aae-gan/140800.png
# /kaggle/input/aae-gan/176800.png
# /kaggle/input/aae-gan/20800.png
# /kaggle/input/aae-gan/4800.png
# /kaggle/input/aae-gan/64000.png
# /kaggle/input/aae-gan/124400.png
# /kaggle/input/aae-gan/166400.png
# /kaggle/input/aae-gan/147600.png
# /kaggle/input/aae-gan/22400.png
# /kaggle/input/aae-gan/88800.png
# /kaggle/input/aae-gan/131600.png
# /kaggle/input/aae-gan/66400.png
# /kaggle/input/aae-gan/98000.png
# /kaggle/input/aae-gan/119200.png
# /kaggle/input/aae-gan/96000.png
# /kaggle/input/aae-gan/157200.png
# /kaggle/input/aae-gan/128400.png
# /kaggle/input/aae-gan/111200.png
# /kaggle/input/aae-gan/72400.png
# /kaggle/input/aae-gan/97600.png
# /kaggle/input/aae-gan/110400.png
# /kaggle/input/aae-gan/31600.png
# /kaggle/input/aae-gan/128800.png
# /kaggle/input/aae-gan/19200.png
# /kaggle/input/aae-gan/158800.png
# /kaggle/input/aae-gan/176400.png
# /kaggle/input/aae-gan/16800.png
# /kaggle/input/aae-gan/78000.png
# /kaggle/input/aae-gan/102000.png
# /kaggle/input/aae-gan/76000.png
# /kaggle/input/aae-gan/76400.png
# /kaggle/input/aae-gan/48800.png
# /kaggle/input/aae-gan/16000.png
# /kaggle/input/aae-gan/118000.png
# /kaggle/input/aae-gan/100000.png
# /kaggle/input/aae-gan/44000.png
# /kaggle/input/aae-gan/38800.png
# /kaggle/input/aae-gan/101200.png
# /kaggle/input/aae-gan/175600.png
# /kaggle/input/aae-gan/173200.png
# /kaggle/input/aae-gan/116800.png
# /kaggle/input/aae-gan/135600.png
# /kaggle/input/aae-gan/51600.png
# /kaggle/input/aae-gan/32800.png
# /kaggle/input/aae-gan/163600.png
# /kaggle/input/aae-gan/178400.png
# /kaggle/input/aae-gan/43200.png
# /kaggle/input/aae-gan/121200.png
# /kaggle/input/aae-gan/13200.png
# /kaggle/input/aae-gan/186000.png
# /kaggle/input/aae-gan/gan_data_epoch_150
# /kaggle/input/aae-gan/115600.png
# /kaggle/input/aae-gan/56000.png
# /kaggle/input/aae-gan/gan_data_epoch_30
# /kaggle/input/aae-gan/115200.png
# /kaggle/input/aae-gan/88400.png
# /kaggle/input/aae-gan/96800.png
# /kaggle/input/aae-gan/70400.png
# /kaggle/input/aae-gan/150000.png
# /kaggle/input/aae-gan/20000.png
# /kaggle/input/aae-gan/168400.png
# /kaggle/input/aae-gan/90800.png
# /kaggle/input/aae-gan/142400.png
# /kaggle/input/aae-gan/41600.png
# /kaggle/input/aae-gan/178000.png
# /kaggle/input/aae-gan/62800.png
# /kaggle/input/aae-gan/80000.png
# /kaggle/input/aae-gan/107200.png
# /kaggle/input/aae-gan/136800.png
# /kaggle/input/aae-gan/19600.png
# /kaggle/input/aae-gan/46800.png
# /kaggle/input/aae-gan/40400.png
# /kaggle/input/aae-gan/27200.png
# /kaggle/input/aae-gan/108400.png
# /kaggle/input/aae-gan/gan_data_epoch_1
# /kaggle/input/aae-gan/138800.png
# /kaggle/input/aae-gan/11200.png
# /kaggle/input/aae-gan/6800.png
# /kaggle/input/aae-gan/171200.png
# /kaggle/input/aae-gan/60400.png
# /kaggle/input/aae-gan/15600.png
# /kaggle/input/aae-gan/37200.png
# /kaggle/input/aae-gan/159200.png
# /kaggle/input/aae-gan/39600.png
# /kaggle/input/aae-gan/141600.png
# /kaggle/input/aae-gan/50800.png
# /kaggle/input/aae-gan/101600.png
# /kaggle/input/aae-gan/78800.png
# /kaggle/input/aae-gan/3200.png
# /kaggle/input/aae-gan/53200.png
# /kaggle/input/aae-gan/141200.png
# /kaggle/input/aae-gan/99200.png
# /kaggle/input/aae-gan/5200.png
# /kaggle/input/aae-gan/126400.png
# /kaggle/input/aae-gan/63200.png
# /kaggle/input/aae-gan/52400.png
# /kaggle/input/aae-gan/74400.png
# /kaggle/input/aae-gan/8800.png
# /kaggle/input/aae-gan/130800.png
# /kaggle/input/aae-gan/15200.png
# /kaggle/input/aae-gan/67200.png
# /kaggle/input/aae-gan/162800.png
# /kaggle/input/aae-gan/154000.png
# /kaggle/input/aae-gan/156000.png
# /kaggle/input/aae-gan/46400.png
# /kaggle/input/aae-gan/106800.png
# /kaggle/input/aae-gan/118400.png
# /kaggle/input/aae-gan/127200.png
# /kaggle/input/aae-gan/148000.png
# /kaggle/input/aae-gan/129200.png
# /kaggle/input/aae-gan/134400.png
# /kaggle/input/aae-gan/82800.png
# /kaggle/input/aae-gan/173600.png
# /kaggle/input/aae-gan/58000.png
# /kaggle/input/aae-gan/4000.png
# /kaggle/input/aae-gan/72000.png
# /kaggle/input/aae-gan/134000.png
# /kaggle/input/aae-gan/91200.png
# /kaggle/input/aae-gan/95200.png
# /kaggle/input/aae-gan/174400.png
# /kaggle/input/aae-gan/144000.png
# /kaggle/input/aae-gan/21600.png
# /kaggle/input/aae-gan/155600.png
# /kaggle/input/aae-gan/36400.png
# /kaggle/input/aae-gan/160800.png
# /kaggle/input/aae-gan/102800.png
# /kaggle/input/aae-gan/164000.png
# /kaggle/input/aae-gan/gan_data_epoch_200
# /kaggle/input/aae-gan/109600.png
# /kaggle/input/aae-gan/153600.png
# /kaggle/input/aae-gan/135200.png
# /kaggle/input/aae-gan/50400.png
# /kaggle/input/aae-gan/144800.png
# /kaggle/input/aae-gan/84800.png
# /kaggle/input/aae-gan/39200.png
# /kaggle/input/aae-gan/49600.png
# /kaggle/input/aae-gan/100400.png
# /kaggle/input/aae-gan/72800.png
# /kaggle/input/aae-gan/25200.png
# /kaggle/input/aae-gan/21200.png
# /kaggle/input/aae-gan/133600.png
# /kaggle/input/aae-gan/40000.png
# /kaggle/input/aae-gan/81200.png
# /kaggle/input/aae-gan/1600.png
# /kaggle/input/aae-gan/146000.png
# /kaggle/input/aae-gan/138000.png
# /kaggle/input/aae-gan/185600.png
# /kaggle/input/aae-gan/48000.png
# /kaggle/input/aae-gan/66000.png
# /kaggle/input/aae-gan/137600.png
# /kaggle/input/aae-gan/126800.png
# /kaggle/input/aae-gan/27600.png
# /kaggle/input/aae-gan/6400.png
# /kaggle/input/aae-gan/96400.png
# /kaggle/input/aae-gan/183600.png
# /kaggle/input/aae-gan/86400.png
# /kaggle/input/aae-gan/184800.png
# /kaggle/input/aae-gan/26400.png
# /kaggle/input/aae-gan/165600.png
# /kaggle/input/aae-gan/150400.png
# /kaggle/input/aae-gan/42800.png
# /kaggle/input/aae-gan/182800.png
# /kaggle/input/aae-gan/180400.png
# /kaggle/input/aae-gan/58400.png
# /kaggle/input/aae-gan/102400.png
# /kaggle/input/aae-gan/30400.png
# /kaggle/input/aae-gan/82400.png
# /kaggle/input/aae-gan/75200.png
# /kaggle/input/aae-gan/71200.png
# /kaggle/input/aae-gan/179600.png
# /kaggle/input/aae-gan/145600.png
# /kaggle/input/aae-gan/__results__.html
# /kaggle/input/aae-gan/172800.png
# /kaggle/input/aae-gan/151200.png
# /kaggle/input/aae-gan/46000.png
# /kaggle/input/aae-gan/113600.png
# /kaggle/input/aae-gan/146800.png
# /kaggle/input/aae-gan/186800.png
# /kaggle/input/aae-gan/168800.png
# /kaggle/input/aae-gan/149200.png
# /kaggle/input/aae-gan/66800.png
# /kaggle/input/aae-gan/95600.png
# /kaggle/input/aae-gan/169600.png
# /kaggle/input/aae-gan/18000.png
# /kaggle/input/aae-gan/69200.png
# /kaggle/input/aae-gan/142000.png
# /kaggle/input/aae-gan/gan_data_epoch_100
# /kaggle/input/aae-gan/45200.png
# /kaggle/input/aae-gan/132800.png
# /kaggle/input/aae-gan/162400.png
# /kaggle/input/aae-gan/117600.png
# /kaggle/input/aae-gan/29600.png
# /kaggle/input/aae-gan/155200.png
# /kaggle/input/aae-gan/103600.png
# /kaggle/input/aae-gan/83600.png
# /kaggle/input/aae-gan/177200.png
# /kaggle/input/aae-gan/32400.png
# /kaggle/input/aae-gan/53600.png
# /kaggle/input/aae-gan/58800.png
# /kaggle/input/aae-gan/170800.png
# /kaggle/input/aae-gan/34400.png
# /kaggle/input/aae-gan/154400.png
# /kaggle/input/aae-gan/122000.png
# /kaggle/input/aae-gan/180000.png
# /kaggle/input/aae-gan/30800.png
# /kaggle/input/aae-gan/2000.png
# /kaggle/input/aae-gan/188400.png
# /kaggle/input/aae-gan/71600.png
# /kaggle/input/aae-gan/86800.png
# /kaggle/input/aae-gan/166800.png
# /kaggle/input/aae-gan/33600.png
# /kaggle/input/aae-gan/78400.png
# /kaggle/input/aae-gan/159600.png
# /kaggle/input/aae-gan/14000.png
# /kaggle/input/aae-gan/110000.png
# /kaggle/input/aae-gan/57200.png
# /kaggle/input/aae-gan/44800.png
# /kaggle/input/aae-gan/161600.png
# /kaggle/input/aae-gan/120800.png
# /kaggle/input/aae-gan/128000.png
# /kaggle/input/aae-gan/18400.png
# /kaggle/input/aae-gan/152000.png
# /kaggle/input/aae-gan/52000.png
# /kaggle/input/aae-gan/50000.png
# /kaggle/input/aae-gan/gan_data_epoch_10
# /kaggle/input/aae-gan/146400.png
# /kaggle/input/aae-gan/140400.png
# /kaggle/input/aae-gan/12400.png
# /kaggle/input/aae-gan/4400.png
# /kaggle/input/aae-gan/29200.png
# /kaggle/input/aae-gan/179200.png
# /kaggle/input/aae-gan/64400.png
# /kaggle/input/aae-gan/171600.png
# /kaggle/input/aae-gan/20400.png
# /kaggle/input/aae-gan/104800.png
# /kaggle/input/aae-gan/92400.png
# /kaggle/input/aae-gan/105200.png
# /kaggle/input/aae-gan/18800.png
# /kaggle/input/aae-gan/142800.png
# /kaggle/input/aae-gan/82000.png
# /kaggle/input/aae-gan/17200.png
# /kaggle/input/aae-gan/92800.png
# /kaggle/input/aae-gan/24800.png
# /kaggle/input/aae-gan/172400.png
# /kaggle/input/aae-gan/129600.png
# /kaggle/input/aae-gan/134800.png
# /kaggle/input/aae-gan/106000.png
# /kaggle/input/aae-gan/116400.png
# /kaggle/input/aae-gan/108000.png
# /kaggle/input/aae-gan/9200.png
# /kaggle/input/aae-gan/73600.png
# /kaggle/input/aae-gan/84000.png
# /kaggle/input/aae-gan/85200.png
# /kaggle/input/aae-gan/132400.png
# /kaggle/input/aae-gan/26000.png
# /kaggle/input/aae-gan/174000.png
# /kaggle/input/aae-gan/120000.png
# /kaggle/input/aae-gan/104400.png
# /kaggle/input/aae-gan/94000.png
# /kaggle/input/aae-gan/93600.png
# /kaggle/input/aae-gan/123600.png
# /kaggle/input/aae-gan/67600.png
# /kaggle/input/aae-gan/10800.png
# /kaggle/input/aae-gan/54400.png
# /kaggle/input/aae-gan/137200.png
# /kaggle/input/aae-gan/73200.png
# /kaggle/input/aae-gan/77200.png
# /kaggle/input/aae-gan/61600.png
# /kaggle/input/aae-gan/9600.png
# /kaggle/input/aae-gan/110800.png
# /kaggle/input/aae-gan/54000.png
# /kaggle/input/aae-gan/64800.png
# /kaggle/input/aae-gan/52800.png
# /kaggle/input/aae-gan/117200.png
# /kaggle/input/aae-gan/22800.png
# /kaggle/input/aae-gan/143200.png
# /kaggle/input/aae-gan/8000.png
# /kaggle/input/aae-gan/gan_data_epoch_40
# /kaggle/input/aae-gan/70000.png
# /kaggle/input/aae-gan/74800.png
# /kaggle/input/aae-gan/55600.png
# /kaggle/input/aae-gan/156400.png
# /kaggle/input/aae-gan/10400.png
# /kaggle/input/aae-gan/84400.png
# /kaggle/input/aae-gan/164800.png
# /kaggle/input/aae-gan/158000.png
# /kaggle/input/aae-gan/68000.png
# /kaggle/input/aae-gan/148800.png
# /kaggle/input/aae-gan/183200.png
# /kaggle/input/aae-gan/12800.png
# /kaggle/input/aae-gan/153200.png
# /kaggle/input/aae-gan/105600.png
# /kaggle/input/aae-gan/65200.png
# /kaggle/input/aae-gan/37600.png
# /kaggle/input/aae-gan/24400.png
# /kaggle/input/aae-gan/157600.png
# /kaggle/input/aae-gan/168000.png
# /kaggle/input/aae-gan/124000.png
# /kaggle/input/aae-gan/38000.png
# /kaggle/input/aae-gan/34000.png
# /kaggle/input/aae-gan/111600.png
# /kaggle/input/aae-gan/8400.png
# /kaggle/input/aae-gan/176000.png
# /kaggle/input/aae-gan/45600.png
# /kaggle/input/aae-gan/40800.png
# /kaggle/input/aae-gan/167600.png
# /kaggle/input/aae-gan/126000.png
# /kaggle/input/aae-gan/164400.png
# /kaggle/input/aae-gan/151600.png
# /kaggle/input/aae-gan/100800.png
# /kaggle/input/aae-gan/175200.png
# /kaggle/input/aae-gan/85600.png
# /kaggle/input/aae-gan/gan_data_epoch_20
# /kaggle/input/aae-gan/57600.png
# /kaggle/input/aae-gan/47600.png
# /kaggle/input/aae-gan/24000.png
# /kaggle/input/aae-gan/1200.png
# /kaggle/input/aae-gan/47200.png
# /kaggle/input/aae-gan/41200.png
# /kaggle/input/aae-gan/25600.png
# /kaggle/input/aae-gan/143600.png
# /kaggle/input/aae-gan/5600.png
# /kaggle/input/aae-gan/140000.png
# /kaggle/input/aae-gan/__notebook__.ipynb
# /kaggle/input/aae-gan/174800.png
# /kaggle/input/aae-gan/170000.png
# /kaggle/input/aae-gan/112000.png
# /kaggle/input/aae-gan/56400.png
# /kaggle/input/aae-gan/162000.png
# /kaggle/input/aae-gan/180800.png
# /kaggle/input/aae-gan/160000.png
# /kaggle/input/aae-gan/gan_data_epoch_50
# /kaggle/input/aae-gan/178800.png
# /kaggle/input/aae-gan/36800.png
# /kaggle/input/aae-gan/60000.png
# /kaggle/input/aae-gan/31200.png
# /kaggle/input/aae-gan/118800.png
# /kaggle/input/aae-gan/42400.png
# /kaggle/input/aae-gan/103200.png
# /kaggle/input/aae-gan/87600.png
# /kaggle/input/aae-gan/124800.png
# /kaggle/input/aae-gan/55200.png
# /kaggle/input/aae-gan/68400.png
# /kaggle/input/aae-gan/17600.png
# /kaggle/input/aae-gan/147200.png
# /kaggle/input/aae-gan/186400.png
# /kaggle/input/aae-gan/79600.png
# /kaggle/input/aae-gan/169200.png
# /kaggle/input/aae-gan/112400.png
# /kaggle/input/aae-gan/61200.png
# /kaggle/input/aae-gan/35600.png
# /kaggle/input/aae-gan/14800.png
# /kaggle/input/aae-gan/28400.png
# /kaggle/input/aae-gan/92000.png
# /kaggle/input/aae-gan/185200.png
# /kaggle/input/aae-gan/109200.png
# /kaggle/input/aae-gan/125600.png
# /kaggle/input/aae-gan/123200.png
# /kaggle/input/aae-gan/800.png
# /kaggle/input/aae-gan/30000.png
# /kaggle/input/aae-gan/98400.png
# /kaggle/input/aae-gan/90400.png
# /kaggle/input/aae-gan/32000.png
# /kaggle/input/aae-gan/62000.png
# /kaggle/input/aae-gan/86000.png
# /kaggle/input/aae-gan/3600.png
# /kaggle/input/aae-gan/2400.png
# /kaggle/input/aae-gan/65600.png
# /kaggle/input/aae-gan/130000.png
# /kaggle/input/aae-gan/160400.png
# /kaggle/input/aae-gan/60800.png
# /kaggle/input/aae-gan/__output__.json
# /kaggle/input/aae-gan/33200.png
# /kaggle/input/aae-gan/26800.png
# /kaggle/input/aae-gan/114800.png
# /kaggle/input/aae-gan/131200.png
# /kaggle/input/aae-gan/149600.png
# /kaggle/input/aae-gan/163200.png
# /kaggle/input/aae-gan/187200.png
# /kaggle/input/aae-gan/23600.png
# /kaggle/input/aae-gan/144400.png
# /kaggle/input/aae-gan/114400.png
# /kaggle/input/aae-gan/106400.png
# /kaggle/input/aae-gan/80400.png
# /kaggle/input/aae-gan/136400.png
# /kaggle/input/aae-gan/68800.png
# /kaggle/input/aae-gan/63600.png
# /kaggle/input/aae-gan/400.png
# /kaggle/input/aae-gan/122800.png
# /kaggle/input/aae-gan/133200.png
# /kaggle/input/aae-gan/43600.png
# /kaggle/input/aae-gan/120400.png
# /kaggle/input/aae-gan/11600.png
# /kaggle/input/aae-gan/74000.png
# /kaggle/input/aae-gan/177600.png
# /kaggle/input/aae-gan/172000.png
# /kaggle/input/aae-gan/139600.png
# /kaggle/input/aae-gan/10000.png
# /kaggle/input/aae-gan/97200.png
# /kaggle/input/aae-gan/112800.png
# /kaggle/input/aae-gan/79200.png
# /kaggle/input/aae-gan/93200.png
# /kaggle/input/aae-gan/121600.png
# /kaggle/input/aae-gan/125200.png
# /kaggle/input/aae-gan/165200.png
# /kaggle/input/aae-gan/12000.png
# /kaggle/input/aae-gan/22000.png
# /kaggle/input/aae-gan/113200.png
# /kaggle/input/aae-gan/44400.png
# /kaggle/input/aae-gan/2800.png
# /kaggle/input/aae-gan/69600.png
# /kaggle/input/aae-gan/42000.png
# /kaggle/input/aae-gan/145200.png
# /kaggle/input/aae-gan/23200.png
# /kaggle/input/aae-gan/114000.png
# /kaggle/input/aae-gan/36000.png
# /kaggle/input/aae-gan/116000.png
# /kaggle/input/aae-gan/108800.png
# /kaggle/input/aae-gan/150800.png
# /kaggle/input/aae-gan/188000.png
# /kaggle/input/aae-gan/182000.png
# /kaggle/input/aae-gan/34800.png
# /kaggle/input/aae-gan/181600.png
# /kaggle/input/aae-gan/48400.png
# /kaggle/input/aae-gan/16400.png
# /kaggle/input/aae-gan/187600.png
# /kaggle/input/aae-gan/70800.png
# /kaggle/input/aae-gan/104000.png
# /kaggle/input/aae-gan/89600.png
# /kaggle/input/aae-gan/38400.png
# /kaggle/input/aae-gan/54800.png
# /kaggle/input/aae-gan/59600.png
# /kaggle/input/aae-gan/181200.png
# /kaggle/input/aae-gan/136000.png
# /kaggle/input/aae-gan/14400.png
# /kaggle/input/aae-gan/87200.png
# /kaggle/input/aae-gan/88000.png
# /kaggle/input/aae-gan/132000.png
# /kaggle/input/aae-gan/7600.png
# /kaggle/input/aae-gan/89200.png
# /kaggle/input/aae-gan/56800.png
# /kaggle/input/aae-gan/122400.png
# /kaggle/input/aae-gan/152400.png
# /kaggle/input/aae-gan/76800.png
# /kaggle/input/aae-gan/184000.png
# /kaggle/input/aae-gan/35200.png
# /kaggle/input/aae-gan/119600.png
# /kaggle/input/aae-gan/158400.png
# /kaggle/input/aae-gan/51200.png
# /kaggle/input/aae-gan/62400.png
# /kaggle/input/aae-gan/59200.png
# /kaggle/input/aae-gan/152800.png
# /kaggle/input/aae-gan/28000.png
# /kaggle/input/aae-gan/83200.png
# /kaggle/input/aae-gan/94800.png
# /kaggle/input/aae-gan/0.png
# /kaggle/input/aae-gan/182400.png
# /kaggle/input/aae-gan/77600.png
# /kaggle/input/aae-gan/167200.png
# /kaggle/input/aae-gan/75600.png
# /kaggle/input/aae-gan/91600.png
# /kaggle/input/aae-gan/98800.png
# /kaggle/input/aae-gan/13600.png
# /kaggle/input/aae-gan/107600.png
# /kaggle/input/aae-gan/161200.png
# /kaggle/input/aae-gan/81600.png
# /kaggle/input/aae-gan/7200.png
# /kaggle/input/aae-gan/94400.png
# /kaggle/input/aae-gan/154800.png
# /kaggle/input/aae-gan/138400.png
# /kaggle/input/aae-gan/127600.png
# /kaggle/input/aae-gan/166000.png
# /kaggle/input/aae-gan/130400.png
# /kaggle/input/aae-gan/49200.png
# /kaggle/input/aae-gan/139200.png
# /kaggle/input/aae-gan/99600.png
# /kaggle/input/aae-gan/184400.png
# /kaggle/input/aae-gan/156800.png
# /kaggle/input/aae-gan/90000.png
# /kaggle/input/aae-gan/6000.png
# /kaggle/input/aae-gan/custom.css
# /kaggle/input/conditional-gan/80800.png
# /kaggle/input/conditional-gan/170400.png
# /kaggle/input/conditional-gan/148400.png
# /kaggle/input/conditional-gan/176800.png
# /kaggle/input/conditional-gan/20800.png
# /kaggle/input/conditional-gan/4800.png
# /kaggle/input/conditional-gan/64000.png
# /kaggle/input/conditional-gan/124400.png
# /kaggle/input/conditional-gan/166400.png
# /kaggle/input/conditional-gan/147600.png
# /kaggle/input/conditional-gan/22400.png
# /kaggle/input/conditional-gan/88800.png
# /kaggle/input/conditional-gan/131600.png
# /kaggle/input/conditional-gan/66400.png
# /kaggle/input/conditional-gan/98000.png
# /kaggle/input/conditional-gan/119200.png
# /kaggle/input/conditional-gan/96000.png
# /kaggle/input/conditional-gan/157200.png
# /kaggle/input/conditional-gan/128400.png
# /kaggle/input/conditional-gan/111200.png
# /kaggle/input/conditional-gan/72400.png
# /kaggle/input/conditional-gan/97600.png
# /kaggle/input/conditional-gan/110400.png
# /kaggle/input/conditional-gan/31600.png
# /kaggle/input/conditional-gan/128800.png
# /kaggle/input/conditional-gan/158800.png
# /kaggle/input/conditional-gan/176400.png
# /kaggle/input/conditional-gan/16800.png
# /kaggle/input/conditional-gan/78000.png
# /kaggle/input/conditional-gan/102000.png
# /kaggle/input/conditional-gan/76000.png
# /kaggle/input/conditional-gan/76400.png
# /kaggle/input/conditional-gan/48800.png
# /kaggle/input/conditional-gan/16000.png
# /kaggle/input/conditional-gan/118000.png
# /kaggle/input/conditional-gan/100000.png
# /kaggle/input/conditional-gan/44000.png
# /kaggle/input/conditional-gan/38800.png
# /kaggle/input/conditional-gan/101200.png
# /kaggle/input/conditional-gan/175600.png
# /kaggle/input/conditional-gan/173200.png
# /kaggle/input/conditional-gan/116800.png
# /kaggle/input/conditional-gan/135600.png
# /kaggle/input/conditional-gan/51600.png
# /kaggle/input/conditional-gan/32800.png
# /kaggle/input/conditional-gan/163600.png
# /kaggle/input/conditional-gan/178400.png
# /kaggle/input/conditional-gan/43200.png
# /kaggle/input/conditional-gan/121200.png
# /kaggle/input/conditional-gan/13200.png
# /kaggle/input/conditional-gan/186000.png
# /kaggle/input/conditional-gan/gan_data_epoch_150
# /kaggle/input/conditional-gan/115600.png
# /kaggle/input/conditional-gan/56000.png
# /kaggle/input/conditional-gan/gan_data_epoch_30
# /kaggle/input/conditional-gan/115200.png
# /kaggle/input/conditional-gan/88400.png
# /kaggle/input/conditional-gan/96800.png
# /kaggle/input/conditional-gan/70400.png
# /kaggle/input/conditional-gan/150000.png
# /kaggle/input/conditional-gan/20000.png
# /kaggle/input/conditional-gan/168400.png
# /kaggle/input/conditional-gan/90800.png
# /kaggle/input/conditional-gan/142400.png
# /kaggle/input/conditional-gan/41600.png
# /kaggle/input/conditional-gan/178000.png
# /kaggle/input/conditional-gan/62800.png
# /kaggle/input/conditional-gan/80000.png
# /kaggle/input/conditional-gan/107200.png
# /kaggle/input/conditional-gan/136800.png
# /kaggle/input/conditional-gan/46800.png
# /kaggle/input/conditional-gan/40400.png
# /kaggle/input/conditional-gan/27200.png
# /kaggle/input/conditional-gan/108400.png
# /kaggle/input/conditional-gan/gan_data_epoch_1
# /kaggle/input/conditional-gan/138800.png
# /kaggle/input/conditional-gan/11200.png
# /kaggle/input/conditional-gan/6800.png
# /kaggle/input/conditional-gan/171200.png
# /kaggle/input/conditional-gan/60400.png
# /kaggle/input/conditional-gan/15600.png
# /kaggle/input/conditional-gan/37200.png
# /kaggle/input/conditional-gan/159200.png
# /kaggle/input/conditional-gan/39600.png
# /kaggle/input/conditional-gan/50800.png
# /kaggle/input/conditional-gan/101600.png
# /kaggle/input/conditional-gan/78800.png
# /kaggle/input/conditional-gan/3200.png
# /kaggle/input/conditional-gan/53200.png
# /kaggle/input/conditional-gan/99200.png
# /kaggle/input/conditional-gan/5200.png
# /kaggle/input/conditional-gan/126400.png
# /kaggle/input/conditional-gan/63200.png
# /kaggle/input/conditional-gan/52400.png
# /kaggle/input/conditional-gan/74400.png
# /kaggle/input/conditional-gan/8800.png
# /kaggle/input/conditional-gan/130800.png
# /kaggle/input/conditional-gan/15200.png
# /kaggle/input/conditional-gan/67200.png
# /kaggle/input/conditional-gan/162800.png
# /kaggle/input/conditional-gan/154000.png
# /kaggle/input/conditional-gan/156000.png
# /kaggle/input/conditional-gan/46400.png
# /kaggle/input/conditional-gan/106800.png
# /kaggle/input/conditional-gan/118400.png
# /kaggle/input/conditional-gan/127200.png
# /kaggle/input/conditional-gan/148000.png
# /kaggle/input/conditional-gan/129200.png
# /kaggle/input/conditional-gan/134400.png
# /kaggle/input/conditional-gan/82800.png
# /kaggle/input/conditional-gan/173600.png
# /kaggle/input/conditional-gan/58000.png
# /kaggle/input/conditional-gan/4000.png
# /kaggle/input/conditional-gan/72000.png
# /kaggle/input/conditional-gan/134000.png
# /kaggle/input/conditional-gan/91200.png
# /kaggle/input/conditional-gan/95200.png
# /kaggle/input/conditional-gan/174400.png
# /kaggle/input/conditional-gan/144000.png
# /kaggle/input/conditional-gan/21600.png
# /kaggle/input/conditional-gan/155600.png
# /kaggle/input/conditional-gan/36400.png
# /kaggle/input/conditional-gan/160800.png
# /kaggle/input/conditional-gan/102800.png
# /kaggle/input/conditional-gan/164000.png
# /kaggle/input/conditional-gan/gan_data_epoch_200
# /kaggle/input/conditional-gan/109600.png
# /kaggle/input/conditional-gan/153600.png
# /kaggle/input/conditional-gan/135200.png
# /kaggle/input/conditional-gan/50400.png
# /kaggle/input/conditional-gan/144800.png
# /kaggle/input/conditional-gan/84800.png
# /kaggle/input/conditional-gan/39200.png
# /kaggle/input/conditional-gan/49600.png
# /kaggle/input/conditional-gan/100400.png
# /kaggle/input/conditional-gan/72800.png
# /kaggle/input/conditional-gan/25200.png
# /kaggle/input/conditional-gan/21200.png
# /kaggle/input/conditional-gan/133600.png
# /kaggle/input/conditional-gan/40000.png
# /kaggle/input/conditional-gan/81200.png
# /kaggle/input/conditional-gan/146000.png
# /kaggle/input/conditional-gan/138000.png
# /kaggle/input/conditional-gan/185600.png
# /kaggle/input/conditional-gan/48000.png
# /kaggle/input/conditional-gan/66000.png
# /kaggle/input/conditional-gan/137600.png
# /kaggle/input/conditional-gan/126800.png
# /kaggle/input/conditional-gan/27600.png
# /kaggle/input/conditional-gan/6400.png
# /kaggle/input/conditional-gan/96400.png
# /kaggle/input/conditional-gan/183600.png
# /kaggle/input/conditional-gan/86400.png
# /kaggle/input/conditional-gan/184800.png
# /kaggle/input/conditional-gan/26400.png
# /kaggle/input/conditional-gan/165600.png
# /kaggle/input/conditional-gan/150400.png
# /kaggle/input/conditional-gan/42800.png
# /kaggle/input/conditional-gan/182800.png
# /kaggle/input/conditional-gan/180400.png
# /kaggle/input/conditional-gan/58400.png
# /kaggle/input/conditional-gan/102400.png
# /kaggle/input/conditional-gan/30400.png
# /kaggle/input/conditional-gan/82400.png
# /kaggle/input/conditional-gan/75200.png
# /kaggle/input/conditional-gan/71200.png
# /kaggle/input/conditional-gan/179600.png
# /kaggle/input/conditional-gan/145600.png
# /kaggle/input/conditional-gan/__results__.html
# /kaggle/input/conditional-gan/172800.png
# /kaggle/input/conditional-gan/151200.png
# /kaggle/input/conditional-gan/46000.png
# /kaggle/input/conditional-gan/113600.png
# /kaggle/input/conditional-gan/146800.png
# /kaggle/input/conditional-gan/186800.png
# /kaggle/input/conditional-gan/168800.png
# /kaggle/input/conditional-gan/149200.png
# /kaggle/input/conditional-gan/66800.png
# /kaggle/input/conditional-gan/95600.png
# /kaggle/input/conditional-gan/169600.png
# /kaggle/input/conditional-gan/18000.png
# /kaggle/input/conditional-gan/69200.png
# /kaggle/input/conditional-gan/142000.png
# /kaggle/input/conditional-gan/gan_data_epoch_100
# /kaggle/input/conditional-gan/45200.png
# /kaggle/input/conditional-gan/132800.png
# /kaggle/input/conditional-gan/162400.png
# /kaggle/input/conditional-gan/117600.png
# /kaggle/input/conditional-gan/29600.png
# /kaggle/input/conditional-gan/155200.png
# /kaggle/input/conditional-gan/103600.png
# /kaggle/input/conditional-gan/83600.png
# /kaggle/input/conditional-gan/177200.png
# /kaggle/input/conditional-gan/32400.png
# /kaggle/input/conditional-gan/53600.png
# /kaggle/input/conditional-gan/58800.png
# /kaggle/input/conditional-gan/170800.png
# /kaggle/input/conditional-gan/34400.png
# /kaggle/input/conditional-gan/154400.png
# /kaggle/input/conditional-gan/122000.png
# /kaggle/input/conditional-gan/180000.png
# /kaggle/input/conditional-gan/30800.png
# /kaggle/input/conditional-gan/2000.png
# /kaggle/input/conditional-gan/71600.png
# /kaggle/input/conditional-gan/86800.png
# /kaggle/input/conditional-gan/166800.png
# /kaggle/input/conditional-gan/33600.png
# /kaggle/input/conditional-gan/78400.png
# /kaggle/input/conditional-gan/159600.png
# /kaggle/input/conditional-gan/14000.png
# /kaggle/input/conditional-gan/110000.png
# /kaggle/input/conditional-gan/57200.png
# /kaggle/input/conditional-gan/44800.png
# /kaggle/input/conditional-gan/161600.png
# /kaggle/input/conditional-gan/120800.png
# /kaggle/input/conditional-gan/128000.png
# /kaggle/input/conditional-gan/18400.png
# /kaggle/input/conditional-gan/152000.png
# /kaggle/input/conditional-gan/52000.png
# /kaggle/input/conditional-gan/50000.png
# /kaggle/input/conditional-gan/gan_data_epoch_10
# /kaggle/input/conditional-gan/146400.png
# /kaggle/input/conditional-gan/140400.png
# /kaggle/input/conditional-gan/12400.png
# /kaggle/input/conditional-gan/4400.png
# /kaggle/input/conditional-gan/29200.png
# /kaggle/input/conditional-gan/179200.png
# /kaggle/input/conditional-gan/64400.png
# /kaggle/input/conditional-gan/171600.png
# /kaggle/input/conditional-gan/20400.png
# /kaggle/input/conditional-gan/104800.png
# /kaggle/input/conditional-gan/92400.png
# /kaggle/input/conditional-gan/105200.png
# /kaggle/input/conditional-gan/142800.png
# /kaggle/input/conditional-gan/82000.png
# /kaggle/input/conditional-gan/17200.png
# /kaggle/input/conditional-gan/92800.png
# /kaggle/input/conditional-gan/24800.png
# /kaggle/input/conditional-gan/172400.png
# /kaggle/input/conditional-gan/129600.png
# /kaggle/input/conditional-gan/134800.png
# /kaggle/input/conditional-gan/106000.png
# /kaggle/input/conditional-gan/116400.png
# /kaggle/input/conditional-gan/108000.png
# /kaggle/input/conditional-gan/9200.png
# /kaggle/input/conditional-gan/73600.png
# /kaggle/input/conditional-gan/84000.png
# /kaggle/input/conditional-gan/85200.png
# /kaggle/input/conditional-gan/132400.png
# /kaggle/input/conditional-gan/26000.png
# /kaggle/input/conditional-gan/174000.png
# /kaggle/input/conditional-gan/120000.png
# /kaggle/input/conditional-gan/104400.png
# /kaggle/input/conditional-gan/93600.png
# /kaggle/input/conditional-gan/123600.png
# /kaggle/input/conditional-gan/67600.png
# /kaggle/input/conditional-gan/10800.png
# /kaggle/input/conditional-gan/54400.png
# /kaggle/input/conditional-gan/137200.png
# /kaggle/input/conditional-gan/73200.png
# /kaggle/input/conditional-gan/77200.png
# /kaggle/input/conditional-gan/61600.png
# /kaggle/input/conditional-gan/110800.png
# /kaggle/input/conditional-gan/54000.png
# /kaggle/input/conditional-gan/64800.png
# /kaggle/input/conditional-gan/52800.png
# /kaggle/input/conditional-gan/117200.png
# /kaggle/input/conditional-gan/22800.png
# /kaggle/input/conditional-gan/143200.png
# /kaggle/input/conditional-gan/8000.png
# /kaggle/input/conditional-gan/gan_data_epoch_40
# /kaggle/input/conditional-gan/70000.png
# /kaggle/input/conditional-gan/74800.png
# /kaggle/input/conditional-gan/55600.png
# /kaggle/input/conditional-gan/156400.png
# /kaggle/input/conditional-gan/10400.png
# /kaggle/input/conditional-gan/84400.png
# /kaggle/input/conditional-gan/164800.png
# /kaggle/input/conditional-gan/158000.png
# /kaggle/input/conditional-gan/68000.png
# /kaggle/input/conditional-gan/148800.png
# /kaggle/input/conditional-gan/183200.png
# /kaggle/input/conditional-gan/12800.png
# /kaggle/input/conditional-gan/153200.png
# /kaggle/input/conditional-gan/105600.png
# /kaggle/input/conditional-gan/65200.png
# /kaggle/input/conditional-gan/24400.png
# /kaggle/input/conditional-gan/157600.png
# /kaggle/input/conditional-gan/168000.png
# /kaggle/input/conditional-gan/124000.png
# /kaggle/input/conditional-gan/34000.png
# /kaggle/input/conditional-gan/111600.png
# /kaggle/input/conditional-gan/8400.png
# /kaggle/input/conditional-gan/176000.png
# /kaggle/input/conditional-gan/45600.png
# /kaggle/input/conditional-gan/40800.png
# /kaggle/input/conditional-gan/167600.png
# /kaggle/input/conditional-gan/126000.png
# /kaggle/input/conditional-gan/164400.png
# /kaggle/input/conditional-gan/151600.png
# /kaggle/input/conditional-gan/100800.png
# /kaggle/input/conditional-gan/175200.png
# /kaggle/input/conditional-gan/85600.png
# /kaggle/input/conditional-gan/gan_data_epoch_20
# /kaggle/input/conditional-gan/57600.png
# /kaggle/input/conditional-gan/24000.png
# /kaggle/input/conditional-gan/41200.png
# /kaggle/input/conditional-gan/25600.png
# /kaggle/input/conditional-gan/143600.png
# /kaggle/input/conditional-gan/5600.png
# /kaggle/input/conditional-gan/140000.png
# /kaggle/input/conditional-gan/__notebook__.ipynb
# /kaggle/input/conditional-gan/174800.png
# /kaggle/input/conditional-gan/170000.png
# /kaggle/input/conditional-gan/112000.png
# /kaggle/input/conditional-gan/56400.png
# /kaggle/input/conditional-gan/162000.png
# /kaggle/input/conditional-gan/180800.png
# /kaggle/input/conditional-gan/160000.png
# /kaggle/input/conditional-gan/gan_data_epoch_50
# /kaggle/input/conditional-gan/178800.png
# /kaggle/input/conditional-gan/36800.png
# /kaggle/input/conditional-gan/60000.png
# /kaggle/input/conditional-gan/31200.png
# /kaggle/input/conditional-gan/118800.png
# /kaggle/input/conditional-gan/42400.png
# /kaggle/input/conditional-gan/103200.png
# /kaggle/input/conditional-gan/87600.png
# /kaggle/input/conditional-gan/124800.png
# /kaggle/input/conditional-gan/55200.png
# /kaggle/input/conditional-gan/68400.png
# /kaggle/input/conditional-gan/17600.png
# /kaggle/input/conditional-gan/147200.png
# /kaggle/input/conditional-gan/186400.png
# /kaggle/input/conditional-gan/79600.png
# /kaggle/input/conditional-gan/169200.png
# /kaggle/input/conditional-gan/112400.png
# /kaggle/input/conditional-gan/61200.png
# /kaggle/input/conditional-gan/35600.png
# /kaggle/input/conditional-gan/14800.png
# /kaggle/input/conditional-gan/92000.png
# /kaggle/input/conditional-gan/185200.png
# /kaggle/input/conditional-gan/109200.png
# /kaggle/input/conditional-gan/125600.png
# /kaggle/input/conditional-gan/123200.png
# /kaggle/input/conditional-gan/800.png
# /kaggle/input/conditional-gan/30000.png
# /kaggle/input/conditional-gan/98400.png
# /kaggle/input/conditional-gan/90400.png
# /kaggle/input/conditional-gan/32000.png
# /kaggle/input/conditional-gan/62000.png
# /kaggle/input/conditional-gan/86000.png
# /kaggle/input/conditional-gan/3600.png
# /kaggle/input/conditional-gan/2400.png
# /kaggle/input/conditional-gan/65600.png
# /kaggle/input/conditional-gan/130000.png
# /kaggle/input/conditional-gan/160400.png
# /kaggle/input/conditional-gan/60800.png
# /kaggle/input/conditional-gan/__output__.json
# /kaggle/input/conditional-gan/33200.png
# /kaggle/input/conditional-gan/26800.png
# /kaggle/input/conditional-gan/114800.png
# /kaggle/input/conditional-gan/131200.png
# /kaggle/input/conditional-gan/149600.png
# /kaggle/input/conditional-gan/163200.png
# /kaggle/input/conditional-gan/187200.png
# /kaggle/input/conditional-gan/23600.png
# /kaggle/input/conditional-gan/144400.png
# /kaggle/input/conditional-gan/114400.png
# /kaggle/input/conditional-gan/106400.png
# /kaggle/input/conditional-gan/80400.png
# /kaggle/input/conditional-gan/136400.png
# /kaggle/input/conditional-gan/68800.png
# /kaggle/input/conditional-gan/63600.png
# /kaggle/input/conditional-gan/400.png
# /kaggle/input/conditional-gan/122800.png
# /kaggle/input/conditional-gan/133200.png
# /kaggle/input/conditional-gan/43600.png
# /kaggle/input/conditional-gan/120400.png
# /kaggle/input/conditional-gan/11600.png
# /kaggle/input/conditional-gan/74000.png
# /kaggle/input/conditional-gan/177600.png
# /kaggle/input/conditional-gan/172000.png
# /kaggle/input/conditional-gan/139600.png
# /kaggle/input/conditional-gan/97200.png
# /kaggle/input/conditional-gan/112800.png
# /kaggle/input/conditional-gan/79200.png
# /kaggle/input/conditional-gan/93200.png
# /kaggle/input/conditional-gan/121600.png
# /kaggle/input/conditional-gan/125200.png
# /kaggle/input/conditional-gan/165200.png
# /kaggle/input/conditional-gan/12000.png
# /kaggle/input/conditional-gan/22000.png
# /kaggle/input/conditional-gan/113200.png
# /kaggle/input/conditional-gan/44400.png
# /kaggle/input/conditional-gan/2800.png
# /kaggle/input/conditional-gan/69600.png
# /kaggle/input/conditional-gan/42000.png
# /kaggle/input/conditional-gan/145200.png
# /kaggle/input/conditional-gan/23200.png
# /kaggle/input/conditional-gan/114000.png
# /kaggle/input/conditional-gan/36000.png
# /kaggle/input/conditional-gan/116000.png
# /kaggle/input/conditional-gan/108800.png
# /kaggle/input/conditional-gan/150800.png
# /kaggle/input/conditional-gan/182000.png
# /kaggle/input/conditional-gan/34800.png
# /kaggle/input/conditional-gan/181600.png
# /kaggle/input/conditional-gan/48400.png
# /kaggle/input/conditional-gan/16400.png
# /kaggle/input/conditional-gan/70800.png
# /kaggle/input/conditional-gan/104000.png
# /kaggle/input/conditional-gan/89600.png
# /kaggle/input/conditional-gan/54800.png
# /kaggle/input/conditional-gan/59600.png
# /kaggle/input/conditional-gan/181200.png
# /kaggle/input/conditional-gan/136000.png
# /kaggle/input/conditional-gan/14400.png
# /kaggle/input/conditional-gan/87200.png
# /kaggle/input/conditional-gan/88000.png
# /kaggle/input/conditional-gan/132000.png
# /kaggle/input/conditional-gan/7600.png
# /kaggle/input/conditional-gan/89200.png
# /kaggle/input/conditional-gan/56800.png
# /kaggle/input/conditional-gan/122400.png
# /kaggle/input/conditional-gan/152400.png
# /kaggle/input/conditional-gan/76800.png
# /kaggle/input/conditional-gan/184000.png
# /kaggle/input/conditional-gan/35200.png
# /kaggle/input/conditional-gan/119600.png
# /kaggle/input/conditional-gan/158400.png
# /kaggle/input/conditional-gan/51200.png
# /kaggle/input/conditional-gan/62400.png
# /kaggle/input/conditional-gan/59200.png
# /kaggle/input/conditional-gan/152800.png
# /kaggle/input/conditional-gan/28000.png
# /kaggle/input/conditional-gan/83200.png
# /kaggle/input/conditional-gan/94800.png
# /kaggle/input/conditional-gan/0.png
# /kaggle/input/conditional-gan/182400.png
# /kaggle/input/conditional-gan/77600.png
# /kaggle/input/conditional-gan/167200.png
# /kaggle/input/conditional-gan/75600.png
# /kaggle/input/conditional-gan/91600.png
# /kaggle/input/conditional-gan/98800.png
# /kaggle/input/conditional-gan/13600.png
# /kaggle/input/conditional-gan/107600.png
# /kaggle/input/conditional-gan/161200.png
# /kaggle/input/conditional-gan/81600.png
# /kaggle/input/conditional-gan/7200.png
# /kaggle/input/conditional-gan/154800.png
# /kaggle/input/conditional-gan/138400.png
# /kaggle/input/conditional-gan/127600.png
# /kaggle/input/conditional-gan/166000.png
# /kaggle/input/conditional-gan/130400.png
# /kaggle/input/conditional-gan/49200.png
# /kaggle/input/conditional-gan/139200.png
# /kaggle/input/conditional-gan/99600.png
# /kaggle/input/conditional-gan/184400.png
# /kaggle/input/conditional-gan/156800.png
# /kaggle/input/conditional-gan/90000.png
# /kaggle/input/conditional-gan/6000.png
# /kaggle/input/conditional-gan/custom.css
# /kaggle/input/infogan/wiegthed_z2_epoch115.jpg
# /kaggle/input/infogan/wiegthed_z2_epoch65.jpg
# /kaggle/input/infogan/wiegthed_z1_epoch180.jpg
# /kaggle/input/infogan/wiegthed_z1_epoch200.jpg
# /kaggle/input/infogan/wiegthed_z1_epoch45.jpg
# /kaggle/input/infogan/wiegthed_z2_epoch30.jpg
# /kaggle/input/infogan/wiegthed_z2_epoch190.jpg
# /kaggle/input/infogan/wiegthed_z2_epoch150.jpg
# /kaggle/input/infogan/wiegthed_z2_epoch170.jpg
# /kaggle/input/infogan/gan_data_epoch_150
# /kaggle/input/infogan/wiegthed_z1_epoch125.jpg
# /kaggle/input/infogan/wiegthed_z2_epoch25.jpg
# /kaggle/input/infogan/gan_data_epoch_30
# /kaggle/input/infogan/wiegthed_z1_epoch55.jpg
# /kaggle/input/infogan/gan_data_epoch_1
# /kaggle/input/infogan/wiegthed_z2_epoch140.jpg
# /kaggle/input/infogan/wiegthed_z2_epoch45.jpg
# /kaggle/input/infogan/wiegthed_z1_epoch120.jpg
# /kaggle/input/infogan/wiegthed_z2_epoch100.jpg
# /kaggle/input/infogan/wiegthed_z2_epoch120.jpg
# /kaggle/input/infogan/wiegthed_z1_epoch30.jpg
# /kaggle/input/infogan/wiegthed_z2_epoch130.jpg
# /kaggle/input/infogan/wiegthed_z2_epoch60.jpg
# /kaggle/input/infogan/wiegthed_z2_epoch105.jpg
# /kaggle/input/infogan/infogan.log
# /kaggle/input/infogan/wiegthed_z1_epoch135.jpg
# /kaggle/input/infogan/gan_data_epoch_200
# /kaggle/input/infogan/wiegthed_z1_epoch100.jpg
# /kaggle/input/infogan/wiegthed_z2_epoch40.jpg
# /kaggle/input/infogan/wiegthed_z2_epoch75.jpg
# /kaggle/input/infogan/wiegthed_z1_epoch5.jpg
# /kaggle/input/infogan/wiegthed_z1_epoch80.jpg
# /kaggle/input/infogan/wiegthed_z1_epoch70.jpg
# /kaggle/input/infogan/wiegthed_z1_epoch75.jpg
# /kaggle/input/infogan/wiegthed_z1_epoch185.jpg
# /kaggle/input/infogan/__results__.html
# /kaggle/input/infogan/wiegthed_z1_epoch90.jpg
# /kaggle/input/infogan/wiegthed_z2_epoch200.jpg
# /kaggle/input/infogan/wiegthed_z2_epoch90.jpg
# /kaggle/input/infogan/wiegthed_z2_epoch80.jpg
# /kaggle/input/infogan/wiegthed_z1_epoch145.jpg
# /kaggle/input/infogan/wiegthed_z1_epoch140.jpg
# /kaggle/input/infogan/gan_data_epoch_100
# /kaggle/input/infogan/wiegthed_z2_epoch125.jpg
# /kaggle/input/infogan/wiegthed_z2_epoch185.jpg
# /kaggle/input/infogan/gan_data_epoch_10
# /kaggle/input/infogan/wiegthed_z1_epoch190.jpg
# /kaggle/input/infogan/wiegthed_z1_epoch10.jpg
# /kaggle/input/infogan/wiegthed_z2_epoch50.jpg
# /kaggle/input/infogan/wiegthed_z2_epoch155.jpg
# /kaggle/input/infogan/wiegthed_z2_epoch110.jpg
# /kaggle/input/infogan/wiegthed_z1_epoch95.jpg
# /kaggle/input/infogan/wiegthed_z2_epoch55.jpg
# /kaggle/input/infogan/gan_data_epoch_40
# /kaggle/input/infogan/wiegthed_z1_epoch65.jpg
# /kaggle/input/infogan/wiegthed_z1_epoch105.jpg
# /kaggle/input/infogan/wiegthed_z2_epoch195.jpg
# /kaggle/input/infogan/wiegthed_z2_epoch20.jpg
# /kaggle/input/infogan/wiegthed_z2_epoch70.jpg
# /kaggle/input/infogan/wiegthed_z1_epoch60.jpg
# /kaggle/input/infogan/wiegthed_z1_epoch0.jpg
# /kaggle/input/infogan/wiegthed_z2_epoch175.jpg
# /kaggle/input/infogan/wiegthed_z1_epoch35.jpg
# /kaggle/input/infogan/wiegthed_z1_epoch20.jpg
# /kaggle/input/infogan/wiegthed_z2_epoch85.jpg
# /kaggle/input/infogan/wiegthed_z2_epoch135.jpg
# /kaggle/input/infogan/gan_data_epoch_20
# /kaggle/input/infogan/wiegthed_z1_epoch115.jpg
# /kaggle/input/infogan/__notebook__.ipynb
# /kaggle/input/infogan/gan_data_epoch_50
# /kaggle/input/infogan/wiegthed_z1_epoch160.jpg
# /kaggle/input/infogan/wiegthed_z1_epoch155.jpg
# /kaggle/input/infogan/wiegthed_z2_epoch0.jpg
# /kaggle/input/infogan/wiegthed_z2_epoch165.jpg
# /kaggle/input/infogan/__output__.json
# /kaggle/input/infogan/wiegthed_z1_epoch50.jpg
# /kaggle/input/infogan/wiegthed_z2_epoch160.jpg
# /kaggle/input/infogan/wiegthed_z1_epoch25.jpg
# /kaggle/input/infogan/wiegthed_z2_epoch15.jpg
# /kaggle/input/infogan/wiegthed_z2_epoch5.jpg
# /kaggle/input/infogan/wiegthed_z2_epoch35.jpg
# /kaggle/input/infogan/wiegthed_z1_epoch175.jpg
# /kaggle/input/infogan/wiegthed_z1_epoch110.jpg
# /kaggle/input/infogan/wiegthed_z2_epoch10.jpg
# /kaggle/input/infogan/wiegthed_z1_epoch40.jpg
# /kaggle/input/infogan/wiegthed_z2_epoch145.jpg
# /kaggle/input/infogan/wiegthed_z1_epoch85.jpg
# /kaggle/input/infogan/wiegthed_z1_epoch15.jpg
# /kaggle/input/infogan/wiegthed_z1_epoch170.jpg
# /kaggle/input/infogan/wiegthed_z1_epoch195.jpg
# /kaggle/input/infogan/wiegthed_z2_epoch95.jpg
# /kaggle/input/infogan/wiegthed_z1_epoch165.jpg
# /kaggle/input/infogan/wiegthed_z1_epoch130.jpg
# /kaggle/input/infogan/wiegthed_z1_epoch150.jpg
# /kaggle/input/infogan/wiegthed_z2_epoch180.jpg
# /kaggle/input/infogan/custom.css
# /kaggle/input/wgan-implementation/80800.png
# /kaggle/input/wgan-implementation/170400.png
# /kaggle/input/wgan-implementation/28800.png
# /kaggle/input/wgan-implementation/148400.png
# /kaggle/input/wgan-implementation/140800.png
# /kaggle/input/wgan-implementation/176800.png
# /kaggle/input/wgan-implementation/20800.png
# /kaggle/input/wgan-implementation/4800.png
# /kaggle/input/wgan-implementation/64000.png
# /kaggle/input/wgan-implementation/124400.png
# /kaggle/input/wgan-implementation/166400.png
# /kaggle/input/wgan-implementation/147600.png
# /kaggle/input/wgan-implementation/22400.png
# /kaggle/input/wgan-implementation/88800.png
# /kaggle/input/wgan-implementation/131600.png
# /kaggle/input/wgan-implementation/66400.png
# /kaggle/input/wgan-implementation/98000.png
# /kaggle/input/wgan-implementation/119200.png
# /kaggle/input/wgan-implementation/96000.png
# /kaggle/input/wgan-implementation/157200.png
# /kaggle/input/wgan-implementation/128400.png
# /kaggle/input/wgan-implementation/111200.png
# /kaggle/input/wgan-implementation/72400.png
# /kaggle/input/wgan-implementation/97600.png
# /kaggle/input/wgan-implementation/110400.png
# /kaggle/input/wgan-implementation/31600.png
# /kaggle/input/wgan-implementation/128800.png
# /kaggle/input/wgan-implementation/19200.png
# /kaggle/input/wgan-implementation/158800.png
# /kaggle/input/wgan-implementation/176400.png
# /kaggle/input/wgan-implementation/16800.png
# /kaggle/input/wgan-implementation/78000.png
# /kaggle/input/wgan-implementation/102000.png
# /kaggle/input/wgan-implementation/76000.png
# /kaggle/input/wgan-implementation/76400.png
# /kaggle/input/wgan-implementation/48800.png
# /kaggle/input/wgan-implementation/16000.png
# /kaggle/input/wgan-implementation/118000.png
# /kaggle/input/wgan-implementation/100000.png
# /kaggle/input/wgan-implementation/44000.png
# /kaggle/input/wgan-implementation/38800.png
# /kaggle/input/wgan-implementation/101200.png
# /kaggle/input/wgan-implementation/175600.png
# /kaggle/input/wgan-implementation/173200.png
# /kaggle/input/wgan-implementation/116800.png
# /kaggle/input/wgan-implementation/135600.png
# /kaggle/input/wgan-implementation/51600.png
# /kaggle/input/wgan-implementation/32800.png
# /kaggle/input/wgan-implementation/163600.png
# /kaggle/input/wgan-implementation/178400.png
# /kaggle/input/wgan-implementation/43200.png
# /kaggle/input/wgan-implementation/121200.png
# /kaggle/input/wgan-implementation/13200.png
# /kaggle/input/wgan-implementation/186000.png
# /kaggle/input/wgan-implementation/gan_data_epoch_150
# /kaggle/input/wgan-implementation/115600.png
# /kaggle/input/wgan-implementation/56000.png
# /kaggle/input/wgan-implementation/gan_data_epoch_30
# /kaggle/input/wgan-implementation/115200.png
# /kaggle/input/wgan-implementation/88400.png
# /kaggle/input/wgan-implementation/96800.png
# /kaggle/input/wgan-implementation/70400.png
# /kaggle/input/wgan-implementation/150000.png
# /kaggle/input/wgan-implementation/20000.png
# /kaggle/input/wgan-implementation/168400.png
# /kaggle/input/wgan-implementation/90800.png
# /kaggle/input/wgan-implementation/142400.png
# /kaggle/input/wgan-implementation/41600.png
# /kaggle/input/wgan-implementation/178000.png
# /kaggle/input/wgan-implementation/62800.png
# /kaggle/input/wgan-implementation/80000.png
# /kaggle/input/wgan-implementation/107200.png
# /kaggle/input/wgan-implementation/136800.png
# /kaggle/input/wgan-implementation/19600.png
# /kaggle/input/wgan-implementation/46800.png
# /kaggle/input/wgan-implementation/40400.png
# /kaggle/input/wgan-implementation/27200.png
# /kaggle/input/wgan-implementation/108400.png
# /kaggle/input/wgan-implementation/gan_data_epoch_1
# /kaggle/input/wgan-implementation/138800.png
# /kaggle/input/wgan-implementation/11200.png
# /kaggle/input/wgan-implementation/6800.png
# /kaggle/input/wgan-implementation/171200.png
# /kaggle/input/wgan-implementation/60400.png
# /kaggle/input/wgan-implementation/15600.png
# /kaggle/input/wgan-implementation/37200.png
# /kaggle/input/wgan-implementation/159200.png
# /kaggle/input/wgan-implementation/39600.png
# /kaggle/input/wgan-implementation/141600.png
# /kaggle/input/wgan-implementation/50800.png
# /kaggle/input/wgan-implementation/101600.png
# /kaggle/input/wgan-implementation/78800.png
# /kaggle/input/wgan-implementation/3200.png
# /kaggle/input/wgan-implementation/53200.png
# /kaggle/input/wgan-implementation/141200.png
# /kaggle/input/wgan-implementation/99200.png
# /kaggle/input/wgan-implementation/5200.png
# /kaggle/input/wgan-implementation/126400.png
# /kaggle/input/wgan-implementation/63200.png
# /kaggle/input/wgan-implementation/52400.png
# /kaggle/input/wgan-implementation/74400.png
# /kaggle/input/wgan-implementation/8800.png
# /kaggle/input/wgan-implementation/130800.png
# /kaggle/input/wgan-implementation/15200.png
# /kaggle/input/wgan-implementation/67200.png
# /kaggle/input/wgan-implementation/162800.png
# /kaggle/input/wgan-implementation/154000.png
# /kaggle/input/wgan-implementation/156000.png
# /kaggle/input/wgan-implementation/46400.png
# /kaggle/input/wgan-implementation/106800.png
# /kaggle/input/wgan-implementation/118400.png
# /kaggle/input/wgan-implementation/127200.png
# /kaggle/input/wgan-implementation/148000.png
# /kaggle/input/wgan-implementation/129200.png
# /kaggle/input/wgan-implementation/134400.png
# /kaggle/input/wgan-implementation/82800.png
# /kaggle/input/wgan-implementation/173600.png
# /kaggle/input/wgan-implementation/58000.png
# /kaggle/input/wgan-implementation/4000.png
# /kaggle/input/wgan-implementation/72000.png
# /kaggle/input/wgan-implementation/134000.png
# /kaggle/input/wgan-implementation/91200.png
# /kaggle/input/wgan-implementation/95200.png
# /kaggle/input/wgan-implementation/174400.png
# /kaggle/input/wgan-implementation/144000.png
# /kaggle/input/wgan-implementation/21600.png
# /kaggle/input/wgan-implementation/155600.png
# /kaggle/input/wgan-implementation/36400.png
# /kaggle/input/wgan-implementation/160800.png
# /kaggle/input/wgan-implementation/102800.png
# /kaggle/input/wgan-implementation/164000.png
# /kaggle/input/wgan-implementation/gan_data_epoch_200
# /kaggle/input/wgan-implementation/109600.png
# /kaggle/input/wgan-implementation/153600.png
# /kaggle/input/wgan-implementation/135200.png
# /kaggle/input/wgan-implementation/50400.png
# /kaggle/input/wgan-implementation/144800.png
# /kaggle/input/wgan-implementation/84800.png
# /kaggle/input/wgan-implementation/39200.png
# /kaggle/input/wgan-implementation/49600.png
# /kaggle/input/wgan-implementation/100400.png
# /kaggle/input/wgan-implementation/72800.png
# /kaggle/input/wgan-implementation/25200.png
# /kaggle/input/wgan-implementation/21200.png
# /kaggle/input/wgan-implementation/133600.png
# /kaggle/input/wgan-implementation/40000.png
# /kaggle/input/wgan-implementation/81200.png
# /kaggle/input/wgan-implementation/1600.png
# /kaggle/input/wgan-implementation/146000.png
# /kaggle/input/wgan-implementation/138000.png
# /kaggle/input/wgan-implementation/185600.png
# /kaggle/input/wgan-implementation/48000.png
# /kaggle/input/wgan-implementation/66000.png
# /kaggle/input/wgan-implementation/137600.png
# /kaggle/input/wgan-implementation/126800.png
# /kaggle/input/wgan-implementation/27600.png
# /kaggle/input/wgan-implementation/6400.png
# /kaggle/input/wgan-implementation/96400.png
# /kaggle/input/wgan-implementation/183600.png
# /kaggle/input/wgan-implementation/86400.png
# /kaggle/input/wgan-implementation/184800.png
# /kaggle/input/wgan-implementation/26400.png
# /kaggle/input/wgan-implementation/165600.png
# /kaggle/input/wgan-implementation/150400.png
# /kaggle/input/wgan-implementation/42800.png
# /kaggle/input/wgan-implementation/182800.png
# /kaggle/input/wgan-implementation/180400.png
# /kaggle/input/wgan-implementation/58400.png
# /kaggle/input/wgan-implementation/102400.png
# /kaggle/input/wgan-implementation/30400.png
# /kaggle/input/wgan-implementation/82400.png
# /kaggle/input/wgan-implementation/75200.png
# /kaggle/input/wgan-implementation/71200.png
# /kaggle/input/wgan-implementation/179600.png
# /kaggle/input/wgan-implementation/145600.png
# /kaggle/input/wgan-implementation/__results__.html
# /kaggle/input/wgan-implementation/172800.png
# /kaggle/input/wgan-implementation/151200.png
# /kaggle/input/wgan-implementation/46000.png
# /kaggle/input/wgan-implementation/113600.png
# /kaggle/input/wgan-implementation/146800.png
# /kaggle/input/wgan-implementation/186800.png
# /kaggle/input/wgan-implementation/168800.png
# /kaggle/input/wgan-implementation/149200.png
# /kaggle/input/wgan-implementation/66800.png
# /kaggle/input/wgan-implementation/95600.png
# /kaggle/input/wgan-implementation/169600.png
# /kaggle/input/wgan-implementation/18000.png
# /kaggle/input/wgan-implementation/69200.png
# /kaggle/input/wgan-implementation/142000.png
# /kaggle/input/wgan-implementation/gan_data_epoch_100
# /kaggle/input/wgan-implementation/45200.png
# /kaggle/input/wgan-implementation/132800.png
# /kaggle/input/wgan-implementation/162400.png
# /kaggle/input/wgan-implementation/117600.png
# /kaggle/input/wgan-implementation/29600.png
# /kaggle/input/wgan-implementation/155200.png
# /kaggle/input/wgan-implementation/103600.png
# /kaggle/input/wgan-implementation/83600.png
# /kaggle/input/wgan-implementation/177200.png
# /kaggle/input/wgan-implementation/32400.png
# /kaggle/input/wgan-implementation/53600.png
# /kaggle/input/wgan-implementation/58800.png
# /kaggle/input/wgan-implementation/170800.png
# /kaggle/input/wgan-implementation/34400.png
# /kaggle/input/wgan-implementation/154400.png
# /kaggle/input/wgan-implementation/122000.png
# /kaggle/input/wgan-implementation/180000.png
# /kaggle/input/wgan-implementation/30800.png
# /kaggle/input/wgan-implementation/2000.png
# /kaggle/input/wgan-implementation/188400.png
# /kaggle/input/wgan-implementation/71600.png
# /kaggle/input/wgan-implementation/86800.png
# /kaggle/input/wgan-implementation/166800.png
# /kaggle/input/wgan-implementation/33600.png
# /kaggle/input/wgan-implementation/78400.png
# /kaggle/input/wgan-implementation/159600.png
# /kaggle/input/wgan-implementation/14000.png
# /kaggle/input/wgan-implementation/110000.png
# /kaggle/input/wgan-implementation/57200.png
# /kaggle/input/wgan-implementation/44800.png
# /kaggle/input/wgan-implementation/161600.png
# /kaggle/input/wgan-implementation/120800.png
# /kaggle/input/wgan-implementation/128000.png
# /kaggle/input/wgan-implementation/18400.png
# /kaggle/input/wgan-implementation/152000.png
# /kaggle/input/wgan-implementation/52000.png
# /kaggle/input/wgan-implementation/50000.png
# /kaggle/input/wgan-implementation/gan_data_epoch_10
# /kaggle/input/wgan-implementation/146400.png
# /kaggle/input/wgan-implementation/140400.png
# /kaggle/input/wgan-implementation/12400.png
# /kaggle/input/wgan-implementation/4400.png
# /kaggle/input/wgan-implementation/29200.png
# /kaggle/input/wgan-implementation/179200.png
# /kaggle/input/wgan-implementation/64400.png
# /kaggle/input/wgan-implementation/171600.png
# /kaggle/input/wgan-implementation/20400.png
# /kaggle/input/wgan-implementation/104800.png
# /kaggle/input/wgan-implementation/92400.png
# /kaggle/input/wgan-implementation/105200.png
# /kaggle/input/wgan-implementation/18800.png
# /kaggle/input/wgan-implementation/142800.png
# /kaggle/input/wgan-implementation/82000.png
# /kaggle/input/wgan-implementation/17200.png
# /kaggle/input/wgan-implementation/92800.png
# /kaggle/input/wgan-implementation/24800.png
# /kaggle/input/wgan-implementation/172400.png
# /kaggle/input/wgan-implementation/129600.png
# /kaggle/input/wgan-implementation/134800.png
# /kaggle/input/wgan-implementation/106000.png
# /kaggle/input/wgan-implementation/116400.png
# /kaggle/input/wgan-implementation/108000.png
# /kaggle/input/wgan-implementation/9200.png
# /kaggle/input/wgan-implementation/73600.png
# /kaggle/input/wgan-implementation/84000.png
# /kaggle/input/wgan-implementation/85200.png
# /kaggle/input/wgan-implementation/132400.png
# /kaggle/input/wgan-implementation/26000.png
# /kaggle/input/wgan-implementation/174000.png
# /kaggle/input/wgan-implementation/120000.png
# /kaggle/input/wgan-implementation/104400.png
# /kaggle/input/wgan-implementation/94000.png
# /kaggle/input/wgan-implementation/93600.png
# /kaggle/input/wgan-implementation/123600.png
# /kaggle/input/wgan-implementation/67600.png
# /kaggle/input/wgan-implementation/10800.png
# /kaggle/input/wgan-implementation/54400.png
# /kaggle/input/wgan-implementation/137200.png
# /kaggle/input/wgan-implementation/73200.png
# /kaggle/input/wgan-implementation/77200.png
# /kaggle/input/wgan-implementation/61600.png
# /kaggle/input/wgan-implementation/9600.png
# /kaggle/input/wgan-implementation/110800.png
# /kaggle/input/wgan-implementation/54000.png
# /kaggle/input/wgan-implementation/64800.png
# /kaggle/input/wgan-implementation/52800.png
# /kaggle/input/wgan-implementation/117200.png
# /kaggle/input/wgan-implementation/22800.png
# /kaggle/input/wgan-implementation/143200.png
# /kaggle/input/wgan-implementation/8000.png
# /kaggle/input/wgan-implementation/gan_data_epoch_40
# /kaggle/input/wgan-implementation/70000.png
# /kaggle/input/wgan-implementation/74800.png
# /kaggle/input/wgan-implementation/55600.png
# /kaggle/input/wgan-implementation/156400.png
# /kaggle/input/wgan-implementation/10400.png
# /kaggle/input/wgan-implementation/84400.png
# /kaggle/input/wgan-implementation/164800.png
# /kaggle/input/wgan-implementation/158000.png
# /kaggle/input/wgan-implementation/68000.png
# /kaggle/input/wgan-implementation/148800.png
# /kaggle/input/wgan-implementation/183200.png
# /kaggle/input/wgan-implementation/12800.png
# /kaggle/input/wgan-implementation/153200.png
# /kaggle/input/wgan-implementation/105600.png
# /kaggle/input/wgan-implementation/65200.png
# /kaggle/input/wgan-implementation/37600.png
# /kaggle/input/wgan-implementation/24400.png
# /kaggle/input/wgan-implementation/157600.png
# /kaggle/input/wgan-implementation/168000.png
# /kaggle/input/wgan-implementation/124000.png
# /kaggle/input/wgan-implementation/38000.png
# /kaggle/input/wgan-implementation/34000.png
# /kaggle/input/wgan-implementation/111600.png
# /kaggle/input/wgan-implementation/8400.png
# /kaggle/input/wgan-implementation/176000.png
# /kaggle/input/wgan-implementation/45600.png
# /kaggle/input/wgan-implementation/40800.png
# /kaggle/input/wgan-implementation/167600.png
# /kaggle/input/wgan-implementation/126000.png
# /kaggle/input/wgan-implementation/164400.png
# /kaggle/input/wgan-implementation/151600.png
# /kaggle/input/wgan-implementation/100800.png
# /kaggle/input/wgan-implementation/175200.png
# /kaggle/input/wgan-implementation/85600.png
# /kaggle/input/wgan-implementation/gan_data_epoch_20
# /kaggle/input/wgan-implementation/57600.png
# /kaggle/input/wgan-implementation/47600.png
# /kaggle/input/wgan-implementation/24000.png
# /kaggle/input/wgan-implementation/1200.png
# /kaggle/input/wgan-implementation/47200.png
# /kaggle/input/wgan-implementation/41200.png
# /kaggle/input/wgan-implementation/25600.png
# /kaggle/input/wgan-implementation/143600.png
# /kaggle/input/wgan-implementation/5600.png
# /kaggle/input/wgan-implementation/140000.png
# /kaggle/input/wgan-implementation/__notebook__.ipynb
# /kaggle/input/wgan-implementation/174800.png
# /kaggle/input/wgan-implementation/170000.png
# /kaggle/input/wgan-implementation/112000.png
# /kaggle/input/wgan-implementation/56400.png
# /kaggle/input/wgan-implementation/162000.png
# /kaggle/input/wgan-implementation/180800.png
# /kaggle/input/wgan-implementation/160000.png
# /kaggle/input/wgan-implementation/gan_data_epoch_50
# /kaggle/input/wgan-implementation/178800.png
# /kaggle/input/wgan-implementation/36800.png
# /kaggle/input/wgan-implementation/60000.png
# /kaggle/input/wgan-implementation/31200.png
# /kaggle/input/wgan-implementation/118800.png
# /kaggle/input/wgan-implementation/42400.png
# /kaggle/input/wgan-implementation/103200.png
# /kaggle/input/wgan-implementation/87600.png
# /kaggle/input/wgan-implementation/124800.png
# /kaggle/input/wgan-implementation/55200.png
# /kaggle/input/wgan-implementation/68400.png
# /kaggle/input/wgan-implementation/17600.png
# /kaggle/input/wgan-implementation/147200.png
# /kaggle/input/wgan-implementation/186400.png
# /kaggle/input/wgan-implementation/79600.png
# /kaggle/input/wgan-implementation/169200.png
# /kaggle/input/wgan-implementation/112400.png
# /kaggle/input/wgan-implementation/61200.png
# /kaggle/input/wgan-implementation/35600.png
# /kaggle/input/wgan-implementation/14800.png
# /kaggle/input/wgan-implementation/28400.png
# /kaggle/input/wgan-implementation/92000.png
# /kaggle/input/wgan-implementation/185200.png
# /kaggle/input/wgan-implementation/109200.png
# /kaggle/input/wgan-implementation/125600.png
# /kaggle/input/wgan-implementation/123200.png
# /kaggle/input/wgan-implementation/800.png
# /kaggle/input/wgan-implementation/30000.png
# /kaggle/input/wgan-implementation/98400.png
# /kaggle/input/wgan-implementation/90400.png
# /kaggle/input/wgan-implementation/32000.png
# /kaggle/input/wgan-implementation/62000.png
# /kaggle/input/wgan-implementation/86000.png
# /kaggle/input/wgan-implementation/3600.png
# /kaggle/input/wgan-implementation/2400.png
# /kaggle/input/wgan-implementation/65600.png
# /kaggle/input/wgan-implementation/130000.png
# /kaggle/input/wgan-implementation/160400.png
# /kaggle/input/wgan-implementation/60800.png
# /kaggle/input/wgan-implementation/__output__.json
# /kaggle/input/wgan-implementation/33200.png
# /kaggle/input/wgan-implementation/26800.png
# /kaggle/input/wgan-implementation/114800.png
# /kaggle/input/wgan-implementation/131200.png
# /kaggle/input/wgan-implementation/149600.png
# /kaggle/input/wgan-implementation/163200.png
# /kaggle/input/wgan-implementation/187200.png
# /kaggle/input/wgan-implementation/23600.png
# /kaggle/input/wgan-implementation/144400.png
# /kaggle/input/wgan-implementation/114400.png
# /kaggle/input/wgan-implementation/106400.png
# /kaggle/input/wgan-implementation/80400.png
# /kaggle/input/wgan-implementation/136400.png
# /kaggle/input/wgan-implementation/68800.png
# /kaggle/input/wgan-implementation/63600.png
# /kaggle/input/wgan-implementation/400.png
# /kaggle/input/wgan-implementation/122800.png
# /kaggle/input/wgan-implementation/133200.png
# /kaggle/input/wgan-implementation/43600.png
# /kaggle/input/wgan-implementation/120400.png
# /kaggle/input/wgan-implementation/11600.png
# /kaggle/input/wgan-implementation/74000.png
# /kaggle/input/wgan-implementation/177600.png
# /kaggle/input/wgan-implementation/172000.png
# /kaggle/input/wgan-implementation/139600.png
# /kaggle/input/wgan-implementation/10000.png
# /kaggle/input/wgan-implementation/97200.png
# /kaggle/input/wgan-implementation/112800.png
# /kaggle/input/wgan-implementation/79200.png
# /kaggle/input/wgan-implementation/93200.png
# /kaggle/input/wgan-implementation/121600.png
# /kaggle/input/wgan-implementation/125200.png
# /kaggle/input/wgan-implementation/165200.png
# /kaggle/input/wgan-implementation/12000.png
# /kaggle/input/wgan-implementation/22000.png
# /kaggle/input/wgan-implementation/113200.png
# /kaggle/input/wgan-implementation/44400.png
# /kaggle/input/wgan-implementation/2800.png
# /kaggle/input/wgan-implementation/69600.png
# /kaggle/input/wgan-implementation/42000.png
# /kaggle/input/wgan-implementation/145200.png
# /kaggle/input/wgan-implementation/23200.png
# /kaggle/input/wgan-implementation/114000.png
# /kaggle/input/wgan-implementation/36000.png
# /kaggle/input/wgan-implementation/116000.png
# /kaggle/input/wgan-implementation/108800.png
# /kaggle/input/wgan-implementation/150800.png
# /kaggle/input/wgan-implementation/188000.png
# /kaggle/input/wgan-implementation/182000.png
# /kaggle/input/wgan-implementation/34800.png
# /kaggle/input/wgan-implementation/181600.png
# /kaggle/input/wgan-implementation/48400.png
# /kaggle/input/wgan-implementation/16400.png
# /kaggle/input/wgan-implementation/187600.png
# /kaggle/input/wgan-implementation/70800.png
# /kaggle/input/wgan-implementation/104000.png
# /kaggle/input/wgan-implementation/89600.png
# /kaggle/input/wgan-implementation/38400.png
# /kaggle/input/wgan-implementation/54800.png
# /kaggle/input/wgan-implementation/59600.png
# /kaggle/input/wgan-implementation/181200.png
# /kaggle/input/wgan-implementation/136000.png
# /kaggle/input/wgan-implementation/14400.png
# /kaggle/input/wgan-implementation/87200.png
# /kaggle/input/wgan-implementation/88000.png
# /kaggle/input/wgan-implementation/132000.png
# /kaggle/input/wgan-implementation/7600.png
# /kaggle/input/wgan-implementation/89200.png
# /kaggle/input/wgan-implementation/56800.png
# /kaggle/input/wgan-implementation/122400.png
# /kaggle/input/wgan-implementation/152400.png
# /kaggle/input/wgan-implementation/76800.png
# /kaggle/input/wgan-implementation/184000.png
# /kaggle/input/wgan-implementation/35200.png
# /kaggle/input/wgan-implementation/119600.png
# /kaggle/input/wgan-implementation/158400.png
# /kaggle/input/wgan-implementation/51200.png
# /kaggle/input/wgan-implementation/62400.png
# /kaggle/input/wgan-implementation/59200.png
# /kaggle/input/wgan-implementation/152800.png
# /kaggle/input/wgan-implementation/28000.png
# /kaggle/input/wgan-implementation/83200.png
# /kaggle/input/wgan-implementation/94800.png
# /kaggle/input/wgan-implementation/0.png
# /kaggle/input/wgan-implementation/182400.png
# /kaggle/input/wgan-implementation/77600.png
# /kaggle/input/wgan-implementation/167200.png
# /kaggle/input/wgan-implementation/75600.png
# /kaggle/input/wgan-implementation/91600.png
# /kaggle/input/wgan-implementation/98800.png
# /kaggle/input/wgan-implementation/13600.png
# /kaggle/input/wgan-implementation/107600.png
# /kaggle/input/wgan-implementation/161200.png
# /kaggle/input/wgan-implementation/81600.png
# /kaggle/input/wgan-implementation/7200.png
# /kaggle/input/wgan-implementation/94400.png
# /kaggle/input/wgan-implementation/154800.png
# /kaggle/input/wgan-implementation/138400.png
# /kaggle/input/wgan-implementation/127600.png
# /kaggle/input/wgan-implementation/166000.png
# /kaggle/input/wgan-implementation/130400.png
# /kaggle/input/wgan-implementation/49200.png
# /kaggle/input/wgan-implementation/139200.png
# /kaggle/input/wgan-implementation/99600.png
# /kaggle/input/wgan-implementation/184400.png
# /kaggle/input/wgan-implementation/156800.png
# /kaggle/input/wgan-implementation/90000.png
# /kaggle/input/wgan-implementation/6000.png
# /kaggle/input/wgan-implementation/custom.css

# %%
from six.moves import urllib    
opener = urllib.request.build_opener()
opener.addheaders = [('User-agent', 'Mozilla/5.0')]
urllib.request.install_opener(opener)

# %%
import numpy as np
import torch
import torchvision
import matplotlib.pyplot as plt
from time import time
from torchvision import datasets, transforms
from torch import nn, optim

# transform = transforms.Compose([transforms.Resize(28),transforms.ToTensor(),
#                               transforms.Normalize((0.5,), (0.5,)),
#                               ])

# trainset = datasets.MNIST(r'..\input\MNIST', download=True, train=True, transform=transform)#(St')
# trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)

# testset = datasets.MNIST(r'..\input\MNIST', download=True, train=False, transform=transform)#(Sv')
# testloader = torch.utils.data.DataLoader(testset, batch_size=64, shuffle=True)

# %%
# final_set = trainset+ testset

# %%
# train_size = int(0.8571 * len(final_set))
# test_size = len(final_set) - train_size
# train_dataset, test_dataset = torch.utils.data.random_split(final_set, [train_size, test_size])

# %%
train_loader = torch.load('../input/mnist-splitter/stdash_dataloader')#,map_location = torch.device('cpu'))
test_loader = torch.load('../input/mnist-splitter/svdash_dataloader')#,map_location = torch.device('cpu'))

# %%
import numpy as np
import torch
import torchvision
import matplotlib.pyplot as plt
from time import time
from torchvision import datasets, transforms
from torch import nn, optim
import argparse
import os
import numpy as np
import math

import torchvision.transforms as transforms
from torchvision.utils import save_image

from torch.utils.data import DataLoader
from torchvision import datasets
from torch.autograd import Variable

import torch.nn as nn
import torch.nn.functional as F
import torch

trainloader = train_loader

dataiter = iter(trainloader) # creating a iterator
images, labels = dataiter.next() # creating images for image and lables for image number (0 to 9) 

print(images.shape)
print(labels.shape)


if torch.cuda.is_available():
  device = 'cuda'
else:
  device = 'cpu'

model=nn.Sequential(nn.Linear(784,128), # 1 layer:- 784 input 128 o/p
                    nn.ReLU(),          # Defining Regular linear unit as activation
                    nn.Linear(128,64),  # 2 Layer:- 128 Input and 64 O/p
                    nn.Tanh(),          # Defining Regular linear unit as activation
                    nn.Linear(64,10),   # 3 Layer:- 64 Input and 10 O/P as (0-9)
                    nn.LogSoftmax(dim=1) # Defining the log softmax to find the probablities for the last output unit
                  ) 
model.to(device)
criterion = nn.NLLLoss() 

images, labels = next(iter(trainloader))
images = images.view(images.shape[0], -1)
images = images.to(device)
labels = labels.to(device)
logps = model(images) #log probabilities
loss = criterion(logps, labels) #calculate the NLL-loss

loss.backward(retain_graph=True) # to calculate gradients of parameter 

# defining the optimiser with stochastic gradient descent and default parameters
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

print('Initial weights - ', model[0].weight)

images, labels = next(iter(trainloader))
images.resize_(64, 784)

# Clear the gradients, do this because gradients are accumulated
optimizer.zero_grad()
images = images.to(device)
labels = labels.to(device)
# Forward pass
output = model(images)
loss = criterion(output, labels)
# the backward pass and update weights
loss.backward()

time0 = time()
epochs = 15 # total number of iteration for training
running_loss_list= []
epochs_list = []
loss_score = []
for e in range(epochs):
    running_loss = 0
    for images, labels in trainloader:
        # Flatenning MNIST images with size [64,784]
        images = images.view(images.shape[0], -1) 
    
        # defining gradient in each epoch as 0
        optimizer.zero_grad()
        images = images.to(device)
        labels = labels.to(device)  
        # modeling for each image batch
        output = model(images)
        
        # calculating the loss
        loss = criterion(output, labels)
        
        # This is where the model learns by backpropagating
        loss.backward(retain_graph=True)
        
        # And optimizes its weights here
        optimizer.step()
        
        # calculating the loss
        running_loss += loss.item()
        
    else:
        print("Epoch {} - Training loss: {}".format(e, running_loss/len(trainloader)))
        loss_score.append(running_loss)
print("\nTraining Time (in minutes) =",(time()-time0)/60)
# Out:
# torch.Size([64, 1, 28, 28])
# torch.Size([64])
# Initial weights -  Parameter containing:
# tensor([[ 0.0191, -0.0183,  0.0094,  ..., -0.0141, -0.0143,  0.0233],
#         [ 0.0112, -0.0009, -0.0283,  ...,  0.0315, -0.0343, -0.0054],
#         [ 0.0201, -0.0225, -0.0179,  ..., -0.0076, -0.0352, -0.0179],
#         ...,
#         [ 0.0217, -0.0211,  0.0152,  ..., -0.0247, -0.0297, -0.0275],
#         [-0.0055,  0.0002,  0.0058,  ..., -0.0013, -0.0012, -0.0289],
#         [-0.0002, -0.0206,  0.0013,  ...,  0.0006, -0.0007, -0.0312]],
#        device='cuda:0', requires_grad=True)
# Epoch 0 - Training loss: 0.41468896323255006
# Epoch 1 - Training loss: 0.18006240437700868
# Epoch 2 - Training loss: 0.13048721982468006
# Epoch 3 - Training loss: 0.10284986959071334
# Epoch 4 - Training loss: 0.08643277878634759
# Epoch 5 - Training loss: 0.07395137800449834
# Epoch 6 - Training loss: 0.06454875341344521
# Epoch 7 - Training loss: 0.056595291219788714
# Epoch 8 - Training loss: 0.048799434661997286
# Epoch 9 - Training loss: 0.04437273016734632
# Epoch 10 - Training loss: 0.039820898045872105
# Epoch 11 - Training loss: 0.034246211031030836
# Epoch 12 - Training loss: 0.03166206635751708
# Epoch 13 - Training loss: 0.028934928479786615
# Epoch 14 - Training loss: 0.02537523394867307
#
# Training Time (in minutes) = 2.8643978357315065

# %%
dcgan_loader = torch.load('../input/conditional-gan/gan_data_epoch_200')#,map_location=torch.device('cpu'))

# %%
#plotting samples
from torchvision.utils import make_grid
for batch_idx, (temp, target) in enumerate(dcgan_loader):
    img_grid = make_grid(temp[0:8,], nrow=8)
    img_target_labels = target[0:8,].numpy()
    break
    
plt.imshow(img_grid.detach().cpu().numpy().transpose((1,2,0)))
plt.rcParams['figure.figsize'] = (10, 2)
plt.title(img_target_labels, size=16)
plt.show()

# %%
correct_count, all_count = 0, 0
for images,labels in dcgan_loader:
  for i in range(len(labels)):
    
    img = images[i].view(1, 784)
    img = img.to('cuda')
    with torch.no_grad():
      
      logps = model(img)

    ps = torch.exp(logps)
    probab = list(ps.cpu().numpy()[0])
    pred_label = probab.index(max(probab))
    true_label = labels.numpy()[i]
    if(true_label == pred_label):
      correct_count += 1
    all_count += 1

print("Number Of Images Tested =", all_count)
print("\nModel Accuracy =", (correct_count/all_count))
# Out:
# Number Of Images Tested = 59997
#
# Model Accuracy = 0.9844658899611647
